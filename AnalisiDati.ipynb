# %% [markdown]
# Elisa Stabilini - Matricola: 28326A
#
# # Comparative analysis training with or without replay buffer

# %%
import gymnasium as gym 
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd 
import numpy as np 
import torch
import tensorflow as tf 
import matplotlib.pyplot as plt
import random
import os
import timeit
import datetime
from pathlib import Path
# Out:
# 2024-09-24 09:26:56.639741: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-09-24 09:26:56.909849: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-24 09:26:57.027758: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-24 09:26:57.061018: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-24 09:26:57.271062: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-24 09:26:58.769245: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
Data_path = '/home/elisa/Desktop/Uni/SecondY/RL/SecondPart/SummerClaude/TrainedDQLearning/Data/'
TrainedDQLearning_plots = '/home/elisa/Desktop/Uni/SecondY/RL/SecondPart/SummerClaude/TrainedDQLearning/Plots'

# %%
file_name = 'rewards_20240809_205157'
rewards = np.load(Data_path + file_name + '.npy')

# %%
# Plot rewards
plt.figure(figsize=(9, 5))
plt.plot(rewards, color='#50B553')
plt.title('Rewards over Episodes')
plt.xlabel('Episode')
plt.ylabel('Total Reward')

imagefile = file_name + '.png'
if not os.path.exists(TrainedDQLearning_plots):
    os.makedirs(TrainedDQLearning_plots)
file_path = os.path.join(TrainedDQLearning_plots, imagefile)
plt.savefig(file_path)
plt.show()

# %% [markdown]
# ### Analisi dati con replay buffer

# %%
file_name = 'rewards_20240811_091314'
rewards = np.load(Data_path + file_name + '.npy')

# %%
# Plot rewards
plt.figure(figsize=(9, 5))
plt.plot(rewards, color='#50B553')
plt.title('Rewards over Episodes')
plt.xlabel('Episode')
plt.ylabel('Total Reward')

imagefile = file_name + '.png'
if not os.path.exists(TrainedDQLearning_plots):
    os.makedirs(TrainedDQLearning_plots)
file_path = os.path.join(TrainedDQLearning_plots, imagefile)
plt.savefig(file_path)
plt.show()

# %% [markdown]
# ### Rewards comparison: standard training vs. replay buffer training

# %%
file_name1 = 'rewards_20240811_091314'
rewards1 = np.load(Data_path + file_name1 + '.npy')
file_name2 = 'rewards_20240809_205157'
rewards2 = np.load(Data_path + file_name2 + '.npy')
file_name = 'comparison1000'

# Plot rewards
plt.figure(figsize=(9, 5))
plt.plot(rewards1, label='No replay', color='#50B553') 
plt.plot(rewards2, label='With replay buffer', color='#3a623b')  
plt.title('Rewards over Episodes - no replay vs. replay buffer')
plt.xlabel('Episode')
plt.ylabel('Total Reward')

# Add legend
plt.legend()  # This will automatically use the labels you defined

imagefile = file_name + '.png'
if not os.path.exists(TrainedDQLearning_plots):
    os.makedirs(TrainedDQLearning_plots)
file_path = os.path.join(TrainedDQLearning_plots, imagefile)
plt.savefig(file_path)

plt.show()
