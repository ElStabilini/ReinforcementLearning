# %% [markdown]
# # REINFORCE algorithm training analysis and performance

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import matplotlib.pyplot as plt
import os
import pickle
from pathlib import Path

# %%
Data_path_TQ1 = '/home/elisa/Desktop/Uni/SecondY/RL/SecondPart/SummerClaude/TrainedQTabular/Data/'
TrainedTQ1_plots = '/home/elisa/Desktop/Uni/SecondY/RL/SecondPart/SummerClaude/TrainedQTabular/Plots'
timename_TQ1 = '_20240801_161349'

# %%
Data_path_TQ2 = '/home/elisa/Desktop/Uni/SecondY/RL/SecondPart/SummerClaude/TrainedQTabular/Data/'
TrainedTQ2_plots = '/home/elisa/Desktop/Uni/SecondY/RL/SecondPart/SummerClaude/TrainedQTabular/Plots'
timename_TQ2 = '_20240802_153057'

# %%
rewards_file_TQ1 = Data_path_TQ1 + 'rewards' + timename_TQ1 + '.npy'
episode_length_file_TQ1 = Data_path_TQ1 + 'episode_length' + timename_TQ1 + '.npy'

# %%
rewards_file_TQ2 = Data_path_TQ2 + 'rewards' + timename_TQ2 + '.npy'
episode_length_file_TQ2 = Data_path_TQ2 + 'episode_length' + timename_TQ2 + '.npy'

# %% [markdown]
# ### Loading data

# %%
# Load the numpy arrays
rewards_TQ1 = np.load(rewards_file_TQ1)
episode_lengths_TQ1 = np.load(episode_length_file_TQ1)

rewards_TQ2 = np.load(rewards_file_TQ2)
episode_lengths_TQ2 = np.load(episode_length_file_TQ2)

# %%
# Plot rewards
plt.figure(figsize=(9, 5))
plt.plot(rewards_TQ2, label='TabularLearning', color='#3a623b')
plt.plot(rewards_TQ1, label='TabularLearning improved', color='#50B553')
plt.title('Rewards over Episodes')
plt.xlabel('Episode')
plt.ylabel('Total Reward')
plt.legend()

imagefile = 'rewards' + timename_TQ1 + '.png'
if not os.path.exists(TrainedTQ1_plots):
    os.makedirs(TrainedTQ1_plots)
file_path = os.path.join(TrainedTQ1_plots, imagefile)
plt.savefig(file_path)
plt.show()

# %%
year = episode_info_DQ[0]['year']
raw_reward_0 = episode_info_DQ[0]['raw_reward']
raw_reward_50 = episode_info_DQ[100]['raw_reward']
raw_reward_200 = episode_info_DQ[900]['raw_reward']

plt.figure(figsize=(9, 5))
plt.plot(raw_reward_0, label='ep. 0', color='#3a623b')
plt.plot(raw_reward_50, label='ep. 50', color='#458C47')  
plt.plot(raw_reward_200, label='ep. 200', color='#50B553')  
plt.title('Raw reward over years - diff. episodes')
plt.xlabel('Year')
plt.ylabel('Raw reward')
plt.legend() 


imagefile = 'rewards' + timename_DQ + '.png'
if not os.path.exists(TrainedDQLearning_plots):
    os.makedirs(TrainedDQLearning_plots)
file_path = os.path.join(TrainedDQLearning_plots, imagefile)
plt.savefig(file_path)
plt.show()

# %% [markdown]
# ### Error Calculation

# %%
errors_DQL = np.load(errors_file_DQ)

print(errors_DQL)
# Out:
# NpzFile '/home/elisa/Desktop/Uni/SecondY/RL/SecondPart/SummerClaude/TrainedDQLearning/Data/training_errors_20241027_081302.npz' with keys: step_errors, episode_errors

# %%
errors_DQL = np.load(errors_file_DQ)

step_error_DQ = errors_DQL['step_errors']
print("Length of avg_error_RE:", len(step_error_DQ))
ep_errors_DQ = errors_DQL['episode_errors']
print("Length of all_error_RE:", len(ep_errors_DQ))
# Out:
# Length of avg_error_RE: 29969
# Length of all_error_RE: 6707

# %%
avg_error = ep_errors_DQ[:6000:6]
print(len(avg_error))
# Out:
# 1000

# %%
file_name = "REINFORCE_errorrs"

plt.figure(figsize=(9, 5))
plt.plot(avg_error, label='DQLearning', color='#50B553') 
plt.title('Error over Episodes')
plt.xlabel('Episode')
plt.ylabel('Error')
plt.legend() 

imagefile = file_name + '.png'
if not os.path.exists(TrainedDQLearning_plots):
    os.makedirs(TrainedDQLearning_plots)
file_path = os.path.join(TrainedDQLearning_plots, imagefile)
plt.savefig(file_path)

plt.show()
